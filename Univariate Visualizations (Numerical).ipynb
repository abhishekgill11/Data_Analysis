# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv("AB_NYC_2019.csv")

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# Histogram

# %%
sns.histplot(data = df, x = "price")
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.histplot(data = df[df["price"]<1000], x = "price")
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.histplot(data = df[df["price"]<500], x = "price")
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.histplot(data = df, x = "availability_365")
# Out:
# <AxesSubplot:xlabel='availability_365', ylabel='Count'>

# %% [markdown]
# now we have large number of values, so we use distplot coz it gives probability distribution of dataset

# %%
sns.distplot(df["price"])
# Out:
# C:\Users\Gill\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.distplot(df["availability_365"])
# Out:
# C:\Users\Gill\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='availability_365', ylabel='Density'>

# %%
sns.distplot(df["reviews_per_month"])
# Out:
# C:\Users\Gill\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='reviews_per_month', ylabel='Density'>

# %% [markdown]
# boxplot gives us outliers and where the min, max values lie in the data set, if we have a small dataset then boxplots are very much essential

# %%
sns.boxplot(y=df["price"])
# Out:
# <AxesSubplot:ylabel='price'>

# %%
sns.boxplot(y=df["availability_365"])
# Out:
# <AxesSubplot:ylabel='availability_365'>

# %%
df2 = sns.load_dataset("titanic")

# %%
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.histplot(data = df2, x = "fare")
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
sns.distplot(df2["fare"])
# Out:
# C:\Users\Gill\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
sns.boxplot(y=df2["fare"])
# Out:
# <AxesSubplot:ylabel='fare'>

# %%
sns.boxplot(y=df2["age"])
# Out:
# <AxesSubplot:ylabel='age'>

# %% [markdown]
# now we can use the violin plot as well, it includes all the values of boxplot as well as the probability distribution

# %%
sns.violinplot(y=df2["age"])
# Out:
# <AxesSubplot:ylabel='age'>
